# %%
import numpy as np
print(np.__version__)
# Out:
# 2.0.2

# %%
array = [3,4,5]
array = array*2
print(array)
# Out:
# [3, 4, 5, 3, 4, 5]

# %%
array = np.array([3,4,5])
array = array*2
print(array)
# Out:
# [ 6  8 10]

# %%
array1 = np.array([[['A', 'B', 'C'], ['E', 'F', 'G'], ['H', 'I', 'J']],
                    [['D', 'K', 'L'], ['M', 'N', 'O'], ['P', 'Q', 'R']],
                    [['S', 'T', 'U'], ['V', 'W', 'X'], ['A', 'H', 'I']]])
print(array1.ndim)
print(array1.shape)
print(array1.size)
print(array1.dtype)
print(array1.itemsize)
print(array1.data)
print(array1[0,1,2])
word = array1[1,0,0]
print(word)
# Out:
# 3
# (3, 3, 3)
# 27
# <U1
# 4
# <memory at 0x7f113dd432e0>
# G
# DIV

# %%
https://github.com/divyamvashistha23-netizen/numpy.git
# Out:
#   File "/tmp/ipykernel_2016/1330129312.py", line 1
#     https://github.com/divyamvashistha23-netizen/numpy.git
#           ^
# SyntaxError: invalid syntax
